# %%
import dhlab.module_update as mu
mu.update('dhlab_v2')
import dhlab_v2 as d2
import pandas as pd
# Out:
# Updated file `C:\Users\larsj\Documents\GitHub\Demo\dhlab_v2.py`

# %%
c = d2.document_corpus(doctype='digibok', from_year = 2000, to_year = 2005, ddk= "839*", limit = 300)

# %%
c
# Out:
#                                    urn  \
# 0  URN:NBN:no-nb_digibok_2009061604007
# 1  URN:NBN:no-nb_digibok_2016071808052
# 2  URN:NBN:no-nb_digibok_2016072808053
# 3  URN:NBN:no-nb_digibok_2008102300051
# 4  URN:NBN:no-nb_digibok_2011080108069
# 5  URN:NBN:no-nb_digibok_2008100104030
# 6  URN:NBN:no-nb_digibok_2011082308055
# 7  URN:NBN:no-nb_digibok_2008102404007
# 8  URN:NBN:no-nb_digibok_2016071848108
# 9  URN:NBN:no-nb_digibok_2009021004158
#
#                                                title  \
# 0  Brødre : Anna, Johannes, Thor og Erlend, 1965-...
# 1                                         Skogbruden
# 2                       Panamaskipet : kriminalroman
# 3                                               Rask
# 4                                            Elskere
# 5                               Fathimas hemmelighet
# 6                  Drapene i Barkvik : kriminalroman
# 7                             Jusqu'au bout du monde
# 8      Karl Gustavs skjebne og eventyr i barneskolen
# 9                                        Trekkfugler
#
#                                              authors  \
# 0                                  Pedersen , Erling
# 1                     Stark , Sigge / Vatne , Victor
# 2                                     Michelet , Jon
# 3                                   Knudsen , Sverre
# 4                                   Pedersen , Bente
# 5              Vik , Walter / Bjone , Elisabeth Vold
# 6                                Ambjørnsen , Ingvar
# 7                                      Hoel , Sigurd
# 8  Lagercrantz , Rose / Lagercrantz , Samuel / Er...
# 9        Fredriksson , Marianne / Øvergaard , Kirsti
#
#                                  oaiid                           sesamid  \
# 0  oai:nb.bibsys.no:990118845684702202  31ef49ab18523d5aac8091e9b50af41d
# 1  oai:nb.bibsys.no:990416319004702202  bd1cf80883fda254159a6c994b2ba1ac
# 2  oai:nb.bibsys.no:990401507634702202  149b8e74761b0ea94dee870e37e79b0d
# 3  oai:nb.bibsys.no:990012713184702202  245d99db9e391260e8f6383debf5ece8
# 4  oai:nb.bibsys.no:990519083604702202  2be7c615ce545d18806621f2925fcdb5
# 5  oai:nb.bibsys.no:990003589914702202  ff68cc88f3c2ffc9fd249c4b357a55e8
# 6  oai:nb.bibsys.no:990516004394702202  46bb0ced006c85a7aa2a3ca7070d7fde
# 7  oai:nb.bibsys.no:990008010894702202  f79d871d041d9e6e2c1ad6bed20965b0
# 8  oai:nb.bibsys.no:990315238704702202  30c0ada39360388f1f9c2194a57f2821
# 9  oai:nb.bibsys.no:990013439124702202  5d821203fd905a7e4f61bdb6509dc4c2
#
#                     isbn10    city timestamp  year           publisher  \
# 0               8203185002    Oslo  20010101  2001           Aschehoug
# 1               8204091265  [Oslo]  20040101  2004                Damm
# 2               8249502272  [Oslo]  20040101  2004             Oktober
# 3               8203243630    Oslo  20000101  2000           Aschehoug
# 4               8250954572    Oslo  20050101  2005           Schibsted
# 5  8202190169 / 8202189500  [Oslo]  20000101  2000            Cappelen
# 6               8202253705  [Oslo]  20050101  2005            Cappelen
# 7               2862609897   Paris  20000101  2000  Éditions Autrement
# 8               8252547494  [Oslo]  20030101  2003    Bokklubbens barn
# 9               8251784840          20000101  2000                Damm
#
#        langs                                           subjects      ddc  \
# 0        nob                                      norsk / prosa  839.823
# 1  nob / swe                                                      839.73
# 2        nob                                                     839.823
# 3        nob                                                     839.823
# 4        nob                                                     839.823
# 5        nob                                                     839.823
# 6        nob  kriminalromaner / norsk / skjønnlitteratur / u...  839.823
# 7  fre / nob                                                     839.823
# 8  nob / swe                      skolen / fortellinger / humor   839.73
# 9  nob / swe  Cross-cultural communication / Immigrants / sk...   839.73
#
#     genres      literaryform  doctype
# 0  fiction  Skjønnlitteratur  digibok
# 1    novel  Skjønnlitteratur  digibok
# 2  fiction  Skjønnlitteratur  digibok
# 3  fiction  Skjønnlitteratur  digibok
# 4    novel  Skjønnlitteratur  digibok
# 5  fiction  Skjønnlitteratur  digibok
# 6    novel  Skjønnlitteratur  digibok
# 7  fiction  Skjønnlitteratur  digibok
# 8  fiction  Skjønnlitteratur  digibok
# 9  fiction  Skjønnlitteratur  digibok

# %%
conc = d2.Concordance(c, "gjerne")

# %%
conc.size
# Out:
# 123

# %%
conc.show(10)
# Out:
# <style  type="text/css" >
# </style><table id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >link</th>        <th class="col_heading level0 col1" >concordance</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row0" class="row_heading level0 row0" >40</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row0_col0" class="data row0 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2009021004158'>URN:NBN:no-nb_digibok_2009021004158</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row0_col1" class="data row0 col1" >" Ja , <b>gjerne</b> . "</td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row1" class="row_heading level0 row1" >77</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row1_col0" class="data row1 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2016071808052'>URN:NBN:no-nb_digibok_2016071808052</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row1_col1" class="data row1 col1" >... Men først ville han <b>gjerne</b> se hvem som var ute på « hans » marker . Den morgenf riske skogsvandreren dukket snart opp under granene , og Jarl så... </td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row2" class="row_heading level0 row2" >42</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row2_col0" class="data row2 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2009061604007'>URN:NBN:no-nb_digibok_2009061604007</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row2_col1" class="data row2 col1" >... Fortsatte det slik , kunne hun like <b>gjerne</b> gå og legge seg med en gang . Se på fjernsyn på rommet og ete litt mer av sjokoladen... </td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row3" class="row_heading level0 row3" >83</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row3_col0" class="data row3 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2016071808052'>URN:NBN:no-nb_digibok_2016071808052</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row3_col1" class="data row3 col1" >... Nå kunne de <b>gjerne</b> skyte ! Her nådde de ham ikke allikevel der oppe f ra . Han reiste seg litt besværlig , de bakbundne hendene hindret ham... </td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row4" class="row_heading level0 row4" >46</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row4_col0" class="data row4 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2009061604007'>URN:NBN:no-nb_digibok_2009061604007</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row4_col1" class="data row4 col1" >... Han hadde ikke ventet det og ble glad , men hun sa at hun dro da <b>gjerne</b> både til skogs og til fjells , bare de kunne... </td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row5" class="row_heading level0 row5" >112</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row5_col0" class="data row5 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2016072808053'>URN:NBN:no-nb_digibok_2016072808053</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row5_col1" class="data row5 col1" >— Aksepteres , sier Boye . — Jeg vil <b>gjerne</b> ha opplest paragraf 233 som jeg er siktet etter , sier Thygesen . — Bare så vi får den rette stemningen av... </td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row6" class="row_heading level0 row6" >73</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row6_col0" class="data row6 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2016071808052'>URN:NBN:no-nb_digibok_2016071808052</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row6_col1" class="data row6 col1" >... Hun ville mer enn <b>gjerne</b> være den som fikk pleie sårene , men da måtte hun ikke vise seg for ivrig , ikke være for fremfusende . Hun... </td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row7" class="row_heading level0 row7" >2</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row7_col0" class="data row7 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2011082308055'>URN:NBN:no-nb_digibok_2011082308055</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row7_col1" class="data row7 col1" >gå opp , og en kvinnestemme som hvisket så høyt at hun like <b>gjerne</b> kunne ha skreket . - Jeg trådde vi to var enige om at det... </td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row8" class="row_heading level0 row8" >47</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row8_col0" class="data row8 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2009061604007'>URN:NBN:no-nb_digibok_2009061604007</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row8_col1" class="data row8 col1" >Lite visste hun at han <b>gjerne</b> skulle ha vært en av dem , om han kunne . Men han hadde latt den tanken fare for lenge siden... </td>
#             </tr>
#             <tr>
#                         <th id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3level0_row9" class="row_heading level0 row9" >58</th>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row9_col0" class="data row9 col0" ><a target='_blank' href = 'https://urn.nb.no/URN:NBN:no-nb_digibok_2009061604007'>URN:NBN:no-nb_digibok_2009061604007</a></td>
#                         <td id="T_d22624f6_4c3e_11ec_b536_a0a4c554f2a3row9_col1" class="data row9 col1" >... Ønsket han å leve barnløst noen år til , ville Angelica mer enn <b>gjerne</b> bli gravid .</td>
#             </tr>
#     </tbody></table>

# %%
tot = d2.totals(200000)

# %%
tot.head(50)
# Out:
#             freq
# .     7655423257
# ,     5052171514
# i     2531262027
# og    2520268056
# -     1314451583
# er    1296198055
# til   1272415735
# det   1132648890
# :     1131598780
# som   1110184118
# på    1034758204
# av    1016010400
# for   1004903709
# en     969393975
# med    897779544
# at     895694332
# )      863219716
# å      821742586
# (      764169143
# har    686197523
# »      569700683
# den    567829145
# de     565348775
# «      552479957
# ikke   526084460
# —      513203202
# var    501952366
# '      482005772
# om     477698633
# fra    474067562
# /      468813971
# I      441548416
# et     416085072
# 1      415727148
# Det    394875430
# *      370931172
# han    352303969
# ?      305660668
# !      302194713
# ^      294449510
# kan    289865987
# seg    283911783
# 2      278247684
# vi     267212040
# "      262067853
# ;      260568403
# r      254498070
# ved    249800781
# vil    240574023
# 3      231344133

# %%
coll1 = d2.Cooccurence(c, 'gjerne', before = 10, after = 0, reference = tot)

# %%
coll2 = d2.Cooccurence(c, 'hjerne', before = 10, after = 0, reference = tot)

# %%
coll1.show().sort_values(by = 'relevance', ascending = False).head(20)
# Out:
#                  counts    relevance
# pliktløp              1  5398.026939
# luksusbil             1  5056.128562
# Ardiles               1  4625.660185
# Bertheus              1  3918.684939
# Jentungen             1  3262.723728
# glupsk                1  3136.392991
# børsten               1  3061.172101
# ludder                1  3035.744278
# Fortsatte             1  2830.648763
# Lønn-                 1  2666.246877
# arrene                1  2598.561352
# svovelkis             1  2568.104167
# kriminalromaner       1  2360.028326
# byråkrat              1  2215.558466
# spakt                 1  2053.434944
# fmgrene               1  2052.083763
# innrømte              1  2011.796644
# kvinnestemme          1  1995.831707
# barnløst              1  1966.343062
# øyelokk               1  1884.134906

# %%
c1 = d2.urn_collocation(urns = list(c.urn), word = 'gjerne', before = 10, after = 0)

# %%
c2 = d2.urn_collocation(urns = list(c.urn), word = 'hjerne', before = 10, after = 0)

# %%
c1['pmi'] = c1['counts']/tot.freq

# %%
c1[c1['counts'] > 10].sort_values(by = 'bdist', ascending = True).head(20)
# Out:
#            counts  dist     bdist           pmi
# like          247   334  1.421687  7.762273e-06
# vil           666  1334  2.026946  2.768379e-06
# ville         388   795  2.089744  6.621089e-06
# skulle        289   595  2.113402  4.523261e-06
# svært          34    70  2.500000  1.719239e-06
# Skulle         12    15  2.500000  6.389596e-06
# veldig         21    42  2.695652  1.466392e-06
# vilde          12    22  3.000000  6.520613e-07
# inderlig       13    25  3.000000  6.565895e-06
# så            477  1436  3.039666  2.104848e-06
# Jeg           438  1373  3.165909  3.648815e-06
# må             56   165  3.189655  4.537539e-07
# tar            27    75  3.275862  8.404574e-07
# enn            70   216  3.277778  7.744571e-07
# kunne         203   663  3.331707  2.250849e-06
# forresten      11    25  3.461538  3.922584e-06
# Eg             45   143  3.468085  5.258175e-06
# jeg           584  2022  3.484642  2.698084e-06
# mer            55   189  3.666667  7.443576e-07
# saa            19    58  3.714286  6.408824e-07

# %%
gj = c1.sort_values(by = 'bdist').head(100).index

# %%
hj = c2.sort_values(by = 'bdist').head(100).index

# %%
[x for x in gj if x not in hj]
# Out:
# ['like',
#  'vil',
#  'ville',
#  'skulle',
#  'svært',
#  'Skulle',
#  'veldig',
#  'fryktelig',
#  'vilde',
#  'inderlig',
#  'så',
#  'Jeg',
#  'må',
#  'tar',
#  'enn',
#  'kunne',
#  'forresten',
#  'Eg',
#  'kall',
#  'saa',
#  'eg',
#  'Vil',
#  'jo',
#  'kunde',
#  'Du',
#  'vi',
#  'hvor',
#  'Ville',
#  'man',
#  'Vi',
#  'Hun',
#  'melder',
#  'dog',
#  'naturligvis',
#  'lot',
#  'Mer',
#  'Svært',
#  'nok',
#  'vel',
#  'derfor',
#  'hjelper',
#  'skriver',
#  'Kunne',
#  'forferdelig',
#  'hun',
#  'Ho',
#  'Hvor',
#  'Han',
#  'forteller',
#  'Så',
#  'tok',
#  'dukker',
#  'bruker',
#  'ting',
#  'blir',
#  'De',
#  'ga',
#  'de',
#  'Man',
#  'du',
#  'no',
#  'Derfor',
#  'Gøril',
#  'likevel',
#  'ønskede',
#  'Sara',
#  'typen',
#  'gjentar',
#  'spørsmål',
#  'Dessuten',
#  'Ibsen',
#  'Folk',
#  '-',
#  'måtte',
#  'ho',
#  'drakk',
#  'so',
#  'stod',
#  'skyld',
#  '...',
#  'La',
#  'da',
#  'gjør',
#  'nu',
#  'At',
#  '«',
#  'Nå',
#  'kone',
#  'hører',
#  'diktene']

# %%
tot.loc[[x for x in hj if x not in gj and x in tot.index]].sort_values(by = 'freq', ascending = False)
# Out:
#                     freq
# i             2531262027
# og            2520268056
# av            1016010400
# for           1004903709
# en             969393975
# med            897779544
# har            686197523
# den            567829145
# ikke           526084460
# '              482005772
# fra            474067562
# I              441548416
# ?              305660668
# !              302194713
# seg            283911783
# hadde          207587228
# sin            120513539
# inn            102809547
# noe             96042263
# Og              82800227
# noen            82585993
# før             80647274
# hans            61463920
# stor            58219218
# samme           53557628
# tre             49013644
# både            47392461
# uten            46800020
# gjennom         40266047
# vår             39273304
# min             35410653
# egen            24803367
# hvert           23142221
# hennes          20092446
# din             17816917
# nesten          17537820
# klar            13971345
# inne            13612939
# født            10107433
# klare            9086355
# felles           7913945
# lever            7307243
# mykje            6574561
# levende          5437313
# utviklet         3747833
# hjerte           3345864
# gram             2547489
# svak             2370889
# svake            1910024
# andres           1857514
# Julie            1765969
# uvanlig          1506570
# kropp            1423655
# manns            1364852
# skarp            1310914
# stakkars         1069904
# menneskets        897594
# naken             663683
# malte             652372
# kunstneriske      646635
# Ibsens            547907
# nerver            399956
# skremte           355257
# kjølige           319401
# bløt              306711
# logiske           296051
# analytisk         179117
# forvirrede        133002
# sinnssyke         132106
# engere             85760
# übrukte            75613
# Jarls              53576
# Webers             43100
# overtroiske        40538
# sjåførens          33712
# ungdommers         21356
# maniske            20532
# forskrudde         20080

# %%
a = d2.ngram_book(word = ['bok', 'boken', 'boka'])

# %%
a.plot()

# %%
s = a.sum(axis = 1)

# %%
((a.transpose()/a.transpose().sum()).transpose()).plot()

# %%
 [(a.loc[x]/s.loc[x]).sum() for x in a.index]

# %%
a
# Out:
#         bok   boka  boken  kohort
# 1950   9859   3480   5118     1.0
# 1951   6937   2478   3849     1.0
# 1952   6256   2583   3342     1.0
# 1953   6825   2656   3936     1.0
# 1954   6680   1956   3631     1.0
# 1955   6796   2038   3955     1.0
# 1956   6031   2118   3329     1.0
# 1957   7096   2136   4278     1.0
# 1958   8104   1976   4854     1.0
# 1959   8864   2368   5099     1.0
# 1960   7811   2364   4612     1.0
# 1961   7273   2736   3976     1.0
# 1962   7756   2555   4809     1.0
# 1963   7825   2825   4617     1.0
# 1964   7648   3021   4342     1.0
# 1965  10821   3688   5275     1.0
# 1966   8533   4133   4651     1.0
# 1967  10869   3822   6593     1.0
# 1968  11300   4203   6840     1.0
# 1969  12501   5073   6659     1.0
# 1970  13444   5883   8156     1.0
# 1971  12237   5766   6977     1.0
# 1972  13110   6741   7769     1.0
# 1973  12242   7161   6693     1.0
# 1974  13092   7620   7387     1.0
# 1975  13376   8088   7125     1.0
# 1976  14698   9336   8323     1.0
# 1977  15792  10148   9516     1.0
# 1978  16210  10437   9441     1.0
# 1979  18482  11699  10302     1.0
# 1980  16280  10706   9352     1.0
# 1981  16743  12396   9456     1.0
# 1982  18262  12720  11289     1.0
# 1983  18690  11920  11899     1.0
# 1984  16644  11928  11881     1.0
# 1985  17659  11935  12573     1.0
# 1986  19615  13017  13454     1.0
# 1987  19301  12629  14257     1.0
# 1988  19017  13898  13621     1.0
# 1989  19254  13744  13786     1.0
# 1990  24686  16658  18382     1.0

# %%
class Ngram_book():

    
    def __init__(self, words = None, title = None, publisher = None, city = None, lang = 'nob', from_year = None, to_year = None, ddk = None, subject = None):
        from datetime import datetime

        
        self.date = datetime.now()
        if to_year is None:
            to_year = self.date.year
        if from_year is None:
            from_year = 1950
        self.from_year = from_year
        self.to_year = to_year
        self.words = words
        self.title = title
        self.publisher = publisher
        self.city = city
        self.lang = lang
        self.ddk = ddk
        self.subject = subject
        self.ngram = d2.ngram_book(word = words, title = title, publisher = publisher, lang = lang,city = city, period = (from_year, to_year), ddk = ddk, topic = subject)
        #self.cohort =  (self.ngram.transpose()/self.ngram.transpose().sum()).transpose()
        return None
    
    def plot(self, **kwargs):
        self.ngram.plot( **kwargs)
    
    def compare(self, another_ngram):
        start_year = max(self.from_year, another_ngram.from_year)
        end_year = min(self.to_year, another_ngram.to_year)
        compare =  (self.ngram.loc[str(start_year):str(end_year)].transpose()/another_ngram.ngram[str(start_year):str(end_year)].transpose().sum()).transpose()
        return compare
    
class Ngram_news(Ngram_book):
        def __init__(self, words = None, title = None, city = None, from_year = None, to_year = None):
            from datetime import datetime


            self.date = datetime.now()
            if to_year is None:
                to_year = self.date.year
            if from_year is None:
                from_year = 1950
            self.from_year = from_year
            self.to_year = to_year
            self.words = words
            self.title = title
            self.ngram = d2.ngram_news(word = words, title = title, period = (from_year, to_year))
            #self.cohort =  (self.ngram.transpose()/self.ngram.transpose().sum()).transpose()
            return None

# %%
z = Ngram_news(words = ['arbeid'])

# %%
z.plot()

# %%
z.compare(x).plot()

# %%
x = Ngram(words = ['sove', 'sover', 'sov','sovet', 'sovende'], from_year = 1850, to_year = 2010)

# %%
y = Ngram(words = ['.',','], from_year = 1000)

# %%
x.plot(lw = 5)

# %%
x.compare(y).plot()

# %%
x.compare(x).plot()

# %%
x.plot()

# %%
x.date.year
# Out:
# 2021
